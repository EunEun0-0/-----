# %%
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# keras.datasets 안에 boston_housing 데이터셋을 로드합니다.
from keras.datasets import boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# 데이터셋의 크기를 확인합니다.
print(len(train_data))
print(len(test_data))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 404
# 102

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1))

model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
model.summary()
# Out:
# C:\ananconda3\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,121 (20.00 KB)
#  Trainable params: 5,121 (20.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_data,
                    train_labels,
                    epochs=100,
                    batch_size=16,
                    validation_split=0.2,
                    verbose=1)

test_mse_score, test_mae_score = model.evaluate(test_data, test_labels)

print(f"테스트 데이터 MAE: {test_mae_score:.2f}")
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 536.3033 - mae: 21.3478 - val_loss: 505.1808 - val_mae: 20.6688
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 429.6859 - mae: 18.9068 - val_loss: 354.9875 - val_mae: 16.9187
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 240.1422 - mae: 13.6779 - val_loss: 196.1254 - val_mae: 11.6229
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 139.9166 - mae: 9.8106 - val_loss: 105.1030 - val_mae: 7.7769
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 58.6279 - mae: 6.0564 - val_loss: 60.4592 - val_mae: 5.7324
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 45.7403 - mae: 4.6170 - val_loss: 43.5423 - val_mae: 4.7873
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.7187 - mae: 3.9799 - val_loss: 32.4168 - val_mae: 4.1729
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.8172 - mae: 3.7529 - val_loss: 29.3597 - val_mae: 3.8841
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.8682 - mae: 3.5929 - val_loss: 25.6650 - val_mae: 3.7692
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.2812 - mae: 3.2591 - val_loss: 23.8713 - val_mae: 3.5639
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.5432 - mae: 3.0950 - val_loss: 23.4633 - val_mae: 3.7330
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.0048 - mae: 2.8558 - val_loss: 22.4322 - val_mae: 3.3849
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.3671 - mae: 2.8336 - val_loss: 20.2863 - val_mae: 3.3549
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.0689 - mae: 2.8504 - val_loss: 18.5450 - val_mae: 3.1520
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.2452 - mae: 2.5870 - val_loss: 20.2418 - val_mae: 3.5410
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.6321 - mae: 2.7259 - val_loss: 17.7579 - val_mae: 3.1143
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.5304 - mae: 2.4280 - val_loss: 17.3621 - val_mae: 3.1350
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.4273 - mae: 2.4345 - val_loss: 16.5137 - val_mae: 3.0486
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.4081 - mae: 2.2325 - val_loss: 16.1296 - val_mae: 2.8966
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9764 - mae: 2.2434 - val_loss: 15.7470 - val_mae: 2.8642
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.4433 - mae: 2.4251 - val_loss: 15.3442 - val_mae: 2.9341
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.8513 - mae: 2.3697 - val_loss: 15.1704 - val_mae: 2.8306
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.2492 - mae: 2.3461 - val_loss: 14.9413 - val_mae: 2.9477
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.0949 - mae: 2.3671 - val_loss: 14.6950 - val_mae: 2.8993
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.9804 - mae: 2.3100 - val_loss: 15.3554 - val_mae: 2.8502
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1560 - mae: 2.0518 - val_loss: 14.7699 - val_mae: 2.8170
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3891 - mae: 2.0956 - val_loss: 15.1374 - val_mae: 2.7558
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.5514 - mae: 2.3341 - val_loss: 14.7888 - val_mae: 2.7323
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9328 - mae: 2.0548 - val_loss: 15.9146 - val_mae: 2.8374
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.1527 - mae: 2.3846 - val_loss: 14.3838 - val_mae: 2.8473
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4918 - mae: 1.9564 - val_loss: 14.9923 - val_mae: 2.6999
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5106 - mae: 2.0990 - val_loss: 14.4592 - val_mae: 2.7378
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6128 - mae: 1.5662 - val_loss: 16.4024 - val_mae: 2.6148
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2157 - mae: 1.5424 - val_loss: 17.8749 - val_mae: 2.6200
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7907 - mae: 1.6222 - val_loss: 15.8499 - val_mae: 2.5602
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8946 - mae: 1.5663 - val_loss: 17.1776 - val_mae: 2.6915
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2181 - mae: 1.7473 - val_loss: 18.0134 - val_mae: 2.6646
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6300 - mae: 1.7849 - val_loss: 16.1648 - val_mae: 2.5400
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9352 - mae: 1.7399 - val_loss: 16.9533 - val_mae: 2.5770
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6917 - mae: 1.6686 - val_loss: 16.6250 - val_mae: 2.5028
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5896 - mae: 1.5503 - val_loss: 16.6195 - val_mae: 2.5849
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0953 - mae: 1.7299 - val_loss: 15.6566 - val_mae: 2.6120
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4171 - mae: 1.6342 - val_loss: 16.7430 - val_mae: 2.6201
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4836 - mae: 1.7180 - val_loss: 17.2548 - val_mae: 2.6362
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0865 - mae: 1.5263 - val_loss: 17.8331 - val_mae: 2.5602
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1885 - mae: 1.5710 - val_loss: 18.4571 - val_mae: 2.6960
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9536 - mae: 1.5571 - val_loss: 16.3261 - val_mae: 2.4857
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5804 - mae: 1.6345 - val_loss: 15.9418 - val_mae: 2.5784
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7902 - mae: 1.6415 - val_loss: 15.4831 - val_mae: 2.4830
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3583 - mae: 1.4531 - val_loss: 17.4271 - val_mae: 2.6155
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4679 - mae: 1.6316 - val_loss: 15.8773 - val_mae: 2.4835
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3998 - mae: 1.5808 - val_loss: 15.8662 - val_mae: 2.5499
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5270 - mae: 1.4486 - val_loss: 17.0913 - val_mae: 2.5989
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1761 - mae: 1.6498 - val_loss: 17.6216 - val_mae: 2.8440
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5294 - mae: 1.5395 - val_loss: 17.6770 - val_mae: 2.6775
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5914 - mae: 1.6662 - val_loss: 16.8018 - val_mae: 2.5666
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9959 - mae: 1.7153 - val_loss: 14.9372 - val_mae: 2.4767
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2773 - mae: 1.4488 - val_loss: 16.9584 - val_mae: 2.7097
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3981 - mae: 1.5548 - val_loss: 16.2760 - val_mae: 2.5676
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.6073 - mae: 2.9468
# 테스트 데이터 MAE: 3.11

# %%
# 모델 학습 히스토리에서 loss, val_loss, mae, val_mae를 차트로 보여줍니다.

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

mae = history_dict['mae']
val_mae = history_dict['val_mae']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, mae, 'b-', label='train_mae')
ax2.plot(epochs, val_mae, 'r-', label='val_mae')
ax2.set_title('Train and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
test_mse_score, test_mae_score = model.evaluate(test_data, test_labels)

print(f"테스트 데이터 MAE: {test_mae_score:.2f}")
print(f"테스트 데이터 MSE: {test_mse_score:.2f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 19.6073 - mae: 2.9468
# 테스트 데이터 MAE: 3.11
# 테스트 데이터 MSE: 23.30

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras import callbacks
from tensorflow.keras import utils
from keras.datasets import reuters

from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

validation_split_point = int(len(train_data) * 0.25)

val_data = train_data[:validation_split_point]
val_labels = train_labels[:validation_split_point]

partial_x_train = train_data[validation_split_point:]
partial_y_train = train_labels[validation_split_point:]

print(len(train_data))
print(len(val_data))
print(len(test_data))
print(len(set(train_labels)))
# Out:
# 8982
# 2245
# 2246
# 46

# %%
def one_hot_encoding(data, dim=10000):
  results = np.zeros((len(data), dim))
  for i, d in enumerate(data):
    results[i, d] = 1.
  return results

x_train = one_hot_encoding(train_data)
x_val = one_hot_encoding(val_data)
x_test = one_hot_encoding(test_data)

y_train = utils.to_categorical(train_labels)
y_val = utils.to_categorical(val_labels)
y_test = utils.to_categorical(test_labels)

# %%
model = models.Sequential()
model.add(layers.Dense(128, activation='relu', input_shape=(10000,)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 128)                 │       1,280,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 46)                  │           2,990 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,292,142 (4.93 MB)
#  Trainable params: 1,291,758 (4.93 MB)
#  Non-trainable params: 384 (1.50 KB)

# %%
checkpoint_cb = ModelCheckpoint(
    'best_reuters_model.keras',    
    monitor='val_loss',          
    save_best_only=True,                           
)

early_stopping_cb = EarlyStopping(
    patience=10,                
    monitor='val_loss',
    restore_best_weights=True,  
)

history = model.fit(
    x_train,                    
    y_train,                      
    epochs=60,
    batch_size=512,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint_cb, early_stopping_cb]
)
# Out:
# Epoch 1/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.2489 - loss: 3.4742 - val_accuracy: 0.7087 - val_loss: 3.2480
# Epoch 2/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6386 - loss: 1.7703 - val_accuracy: 0.7653 - val_loss: 2.8338
# Epoch 3/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7309 - loss: 1.3443 - val_accuracy: 0.7920 - val_loss: 2.4779
# Epoch 4/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7799 - loss: 1.0762 - val_accuracy: 0.8111 - val_loss: 2.1844
# Epoch 5/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8030 - loss: 0.9222 - val_accuracy: 0.8361 - val_loss: 1.8934
# Epoch 6/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8261 - loss: 0.7962 - val_accuracy: 0.8405 - val_loss: 1.6627
# Epoch 7/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8534 - loss: 0.6906 - val_accuracy: 0.8597 - val_loss: 1.4313
# Epoch 8/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8515 - loss: 0.6508 - val_accuracy: 0.8588 - val_loss: 1.1993
# Epoch 9/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8696 - loss: 0.5893 - val_accuracy: 0.8811 - val_loss: 1.0061
# Epoch 10/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8783 - loss: 0.5315 - val_accuracy: 0.8927 - val_loss: 0.7957
# Epoch 11/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8903 - loss: 0.4828 - val_accuracy: 0.8976 - val_loss: 0.7165
# Epoch 12/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8998 - loss: 0.4478 - val_accuracy: 0.9122 - val_loss: 0.5754
# Epoch 13/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9069 - loss: 0.4067 - val_accuracy: 0.9314 - val_loss: 0.4684
# Epoch 14/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9073 - loss: 0.4002 - val_accuracy: 0.9367 - val_loss: 0.3897
# Epoch 15/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9117 - loss: 0.3660 - val_accuracy: 0.9399 - val_loss: 0.3303
# Epoch 16/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9129 - loss: 0.3740 - val_accuracy: 0.9488 - val_loss: 0.2740
# Epoch 17/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9191 - loss: 0.3397 - val_accuracy: 0.9510 - val_loss: 0.2319
# Epoch 18/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9243 - loss: 0.3194 - val_accuracy: 0.9510 - val_loss: 0.2012
# Epoch 19/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9265 - loss: 0.3148 - val_accuracy: 0.9568 - val_loss: 0.1777
# Epoch 20/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9317 - loss: 0.2913 - val_accuracy: 0.9599 - val_loss: 0.1542
# Epoch 21/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9338 - loss: 0.2864 - val_accuracy: 0.9626 - val_loss: 0.1382
# Epoch 22/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9317 - loss: 0.2938 - val_accuracy: 0.9630 - val_loss: 0.1274
# Epoch 23/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9502 - loss: 0.1748 - val_accuracy: 0.9688 - val_loss: 0.0734

# %%
history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
from keras.models import load_model

best_model = load_model('best_reuters_model.keras')
loss, accuracy = best_model.evaluate(x_test, y_test, verbose=0)

print(f"최종 테스트 손실 (Loss): {loss:.4f}")
print(f"최종 테스트 정확도 (Accuracy): {accuracy:.4f}")
# Out:
# 최종 테스트 손실 (Loss): 1.3016
# 최종 테스트 정확도 (Accuracy): 0.8041

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step

# %%
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
x_train = x_train.reshape(-1, 32 * 32 * 3)
x_val = x_val.reshape(-1, 32 * 32 * 3)
x_test = x_test.reshape(-1, 32 * 32 * 3)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %%
model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(3072,)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                      │ (None, 512)                 │       1,573,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,742,474 (6.65 MB)
#  Trainable params: 1,740,682 (6.64 MB)
#  Non-trainable params: 1,792 (7.00 KB)

# %%
utils.plot_model(model, show_shapes=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
checkpoint_cb = ModelCheckpoint(
    'best_cifar10_model.keras',   
    monitor='val_loss',          
    save_best_only=True,         
    verbose=1                    
)

early_stopping_cb = EarlyStopping(
    patience=10,                 
    monitor='val_loss',
    restore_best_weights=True,   
    verbose=1
)

history = model.fit(
    x_train, y_train,
    epochs=60,
    batch_size=128,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint_cb, early_stopping_cb]
)
# Out:
# Epoch 1/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2235 - loss: 2.3994
# Epoch 1: val_loss improved from inf to 1.83781, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - accuracy: 0.2237 - loss: 2.3987 - val_accuracy: 0.3351 - val_loss: 1.8378
# Epoch 2/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3303 - loss: 1.8697
# Epoch 2: val_loss improved from 1.83781 to 1.77704, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.3304 - loss: 1.8696 - val_accuracy: 0.3612 - val_loss: 1.7770
# Epoch 3/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3619 - loss: 1.7577
# Epoch 3: val_loss improved from 1.77704 to 1.76728, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.3619 - loss: 1.7577 - val_accuracy: 0.3736 - val_loss: 1.7673
# Epoch 4/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3838 - loss: 1.7177
# Epoch 4: val_loss improved from 1.76728 to 1.75720, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.3838 - loss: 1.7177 - val_accuracy: 0.3740 - val_loss: 1.7572
# Epoch 5/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3818 - loss: 1.7158
# Epoch 5: val_loss improved from 1.75720 to 1.67421, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.3818 - loss: 1.7158 - val_accuracy: 0.4065 - val_loss: 1.6742
# Epoch 6/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3943 - loss: 1.6889
# Epoch 6: val_loss did not improve from 1.67421
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.3942 - loss: 1.6890 - val_accuracy: 0.3536 - val_loss: 1.7479
# Epoch 7/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3885 - loss: 1.7030
# Epoch 7: val_loss improved from 1.67421 to 1.58982, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.3885 - loss: 1.7030 - val_accuracy: 0.4267 - val_loss: 1.5898
# Epoch 8/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3929 - loss: 1.6906
# Epoch 8: val_loss did not improve from 1.58982
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.3929 - loss: 1.6906 - val_accuracy: 0.3885 - val_loss: 1.6845
# Epoch 9/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3995 - loss: 1.6867
# Epoch 9: val_loss did not improve from 1.58982
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.3994 - loss: 1.6868 - val_accuracy: 0.4230 - val_loss: 1.5923
# Epoch 10/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.3969 - loss: 1.6741
# Epoch 10: val_loss did not improve from 1.58982
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.3968 - loss: 1.6742 - val_accuracy: 0.4374 - val_loss: 1.5986
# Epoch 11/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4043 - loss: 1.6660
# Epoch 11: val_loss improved from 1.58982 to 1.57899, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.4043 - loss: 1.6660 - val_accuracy: 0.4288 - val_loss: 1.5790
# Epoch 12/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4125 - loss: 1.6606
# Epoch 12: val_loss did not improve from 1.57899
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.4125 - loss: 1.6606 - val_accuracy: 0.4256 - val_loss: 1.5834
# Epoch 13/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4065 - loss: 1.6597
# Epoch 13: val_loss improved from 1.57899 to 1.53274, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.4065 - loss: 1.6597 - val_accuracy: 0.4469 - val_loss: 1.5327
# Epoch 14/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4108 - loss: 1.6544
# Epoch 14: val_loss did not improve from 1.53274
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4108 - loss: 1.6544 - val_accuracy: 0.4284 - val_loss: 1.5999
# Epoch 15/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4173 - loss: 1.6341
# Epoch 15: val_loss did not improve from 1.53274
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4172 - loss: 1.6341 - val_accuracy: 0.4388 - val_loss: 1.5628
# Epoch 16/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4157 - loss: 1.6321
# Epoch 16: val_loss improved from 1.53274 to 1.52670, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.4157 - loss: 1.6321 - val_accuracy: 0.4600 - val_loss: 1.5267
# Epoch 17/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4108 - loss: 1.6466
# Epoch 17: val_loss did not improve from 1.52670
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4107 - loss: 1.6467 - val_accuracy: 0.4257 - val_loss: 1.5999
# Epoch 18/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4082 - loss: 1.6455
# Epoch 18: val_loss did not improve from 1.52670
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.4082 - loss: 1.6456 - val_accuracy: 0.4105 - val_loss: 1.6237
# Epoch 19/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4097 - loss: 1.6402
# Epoch 19: val_loss did not improve from 1.52670
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.4098 - loss: 1.6402 - val_accuracy: 0.4321 - val_loss: 1.5671
# Epoch 20/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4169 - loss: 1.6277
# Epoch 20: val_loss improved from 1.52670 to 1.52372, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4169 - loss: 1.6278 - val_accuracy: 0.4556 - val_loss: 1.5237
# Epoch 21/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4182 - loss: 1.6282
# Epoch 21: val_loss did not improve from 1.52372
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.4183 - loss: 1.6282 - val_accuracy: 0.4317 - val_loss: 1.5684
# Epoch 22/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4234 - loss: 1.6199
# Epoch 22: val_loss improved from 1.52372 to 1.50594, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4234 - loss: 1.6200 - val_accuracy: 0.4622 - val_loss: 1.5059
# Epoch 23/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4185 - loss: 1.6183
# Epoch 23: val_loss did not improve from 1.50594
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4184 - loss: 1.6184 - val_accuracy: 0.4321 - val_loss: 1.5771
# Epoch 24/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4238 - loss: 1.6132
# Epoch 24: val_loss did not improve from 1.50594
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4237 - loss: 1.6132 - val_accuracy: 0.4482 - val_loss: 1.5307
# Epoch 25/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.
60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4358 - loss: 1.5795
# Epoch 43: val_loss did not improve from 1.46845
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4358 - loss: 1.5795 - val_accuracy: 0.4561 - val_loss: 1.5099
# Epoch 44/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4447 - loss: 1.5618
# Epoch 44: val_loss did not improve from 1.46845
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4447 - loss: 1.5618 - val_accuracy: 0.4644 - val_loss: 1.4980
# Epoch 45/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4423 - loss: 1.5712
# Epoch 45: val_loss did not improve from 1.46845
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4422 - loss: 1.5712 - val_accuracy: 0.4376 - val_loss: 1.5428
# Epoch 46/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4357 - loss: 1.5825
# Epoch 46: val_loss did not improve from 1.46845
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4357 - loss: 1.5825 - val_accuracy: 0.4662 - val_loss: 1.4864
# Epoch 47/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4356 - loss: 1.5749
# Epoch 47: val_loss improved from 1.46845 to 1.46515, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4356 - loss: 1.5749 - val_accuracy: 0.4706 - val_loss: 1.4652
# Epoch 48/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4354 - loss: 1.5797
# Epoch 48: val_loss did not improve from 1.46515
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4354 - loss: 1.5797 - val_accuracy: 0.4647 - val_loss: 1.4805
# Epoch 49/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4357 - loss: 1.5810
# Epoch 49: val_loss did not improve from 1.46515
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4357 - loss: 1.5810 - val_accuracy: 0.4727 - val_loss: 1.4722
# Epoch 50/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4410 - loss: 1.5670
# Epoch 50: val_loss improved from 1.46515 to 1.45541, saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4409 - loss: 1.5670 - val_accuracy: 0.4754 - val_loss: 1.4554
# Epoch 51/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4382 - loss: 1.5671
# Epoch 51: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.4383 - loss: 1.5671 - val_accuracy: 0.4681 - val_loss: 1.4751
# Epoch 52/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4476 - loss: 1.5566
# Epoch 52: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4476 - loss: 1.5566 - val_accuracy: 0.4637 - val_loss: 1.4812
# Epoch 53/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4434 - loss: 1.5636
# Epoch 53: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - accuracy: 0.4434 - loss: 1.5636 - val_accuracy: 0.4428 - val_loss: 1.5355
# Epoch 54/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4407 - loss: 1.5711
# Epoch 54: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4407 - loss: 1.5710 - val_accuracy: 0.4762 - val_loss: 1.4804
# Epoch 55/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4406 - loss: 1.5634
# Epoch 55: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.4406 - loss: 1.5634 - val_accuracy: 0.4623 - val_loss: 1.4866
# Epoch 56/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4417 - loss: 1.5609
# Epoch 56: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4417 - loss: 1.5610 - val_accuracy: 0.4822 - val_loss: 1.4571
# Epoch 57/60
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4409 - loss: 1.5626
# Epoch 57: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - accuracy: 0.4409 - loss: 1.5626 - val_accuracy: 0.4757 - val_loss: 1.4557
# Epoch 58/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4421 - loss: 1.5625
# Epoch 58: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 28ms/step - accuracy: 0.4421 - loss: 1.5625 - val_accuracy: 0.4770 - val_loss: 1.4605
# Epoch 59/60
# 311/313 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4431 - loss: 1.5553
# Epoch 59: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - accuracy: 0.4431 - loss: 1.5553 - val_accuracy: 0.4691 - val_loss: 1.4770
# Epoch 60/60
# 312/313 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4429 - loss: 1.5656
# Epoch 60: val_loss did not improve from 1.45541
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.4429 - loss: 1.5656 - val_accuracy: 0.4793 - val_loss: 1.4591
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 50.

# %%
history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4769 - loss: 1.4459
# [1.4514362812042236, 0.4758000075817108]

# %% [markdown]
# Accuracy 낮은이유?
#
# image는 4차원 배열이지만 강제로 Dense 를 이용하기 위해 2차원 배열로 바꿨기 때문?
